# %%
import pandas as pd
from pandas_ods_reader import read_ods

# %%
def getLabelList(df):    
    labelList = []
    counter = 0
    for index, row in df.iterrows():
        for i in range(8):
            if row[i] == None:
                row[i] = ""
            if row[i] == "fish":
                labelList.append(0)
                #print("fish")
                break
            elif row[i] == "bird":
                labelList.append(1)
               # print("bird")
                break
            elif row[i] == "salamander":
                labelList.append(2)
                break
            elif row[i] == "frog":
                labelList.append(3)
                break
            elif row[i] == "turtle":
                labelList.append(4)
                break
            elif row[i] == "lizard":
                labelList.append(5)
                break
            elif row[i] == "crocodilian reptile":
                labelList.append(6)
                break
            elif row[i] == "triceratops":
                labelList.append(7)
                break
            elif row[i] == "snake":
                labelList.append(8)
                break
            elif row[i] == "trilobite":
                labelList.append(9)
                break
            elif row[i] == "arachnid":
                labelList.append(10)
                break
            elif row[i] == "centiped":
                labelList.append(11)
                break
            elif row[i] == "mammal":
                labelList.append(12)
                break
            elif row[i] == "coelenterate":
                labelList.append(13)
                break
            elif row[i] == "worm":
                labelList.append(14)
                break
            elif row[i] == "mollusk":
                labelList.append(15)
                break
            elif row[i] == "crustacean":
                labelList.append(16)
                break
            elif row[i] == "insect":
                labelList.append(17)
                break
            elif row[i] == "echinoderm":
                labelList.append(18)
                break
            """
            elif row[i] == "machine":
                labelList.append(19)
                break
            elif row[i] == "clothing":
                labelList.append(20)
                break
            elif row[i] == "musical instrument":
                labelList.append(21)
                break
            elif row[i] == "ship":
                labelList.append(22)
                break
            elif row[i] == "aircraft":
                labelList.append(23)
                break
            elif row[i] == "structure":
                labelList.append(24)
                break
            elif row[i] == "wheeled vehicle":
                labelList.append(25)
                break
            elif row[i] == "measuring instrument":
                labelList.append(26)
                break
            elif row[i] == "container":
                labelList.append(27)
                break
            elif row[i] == "weapon":
                labelList.append(28)
                break
            elif row[i] == "magnifier":
                labelList.append(29)
                break
            elif row[i] == "measuring instrument":
                labelList.append(30)
                break
            elif row[i] == "magnetic compass":
                labelList.append(31)
                break
            elif row[i] == "optical instrument":
                labelList.append(32)
                break
            elif row[i] == "guillotine":
                labelList.append(33)
                break
            elif row[i] == "medical instrument":
                labelList.append(34)
                break
            elif row[i] == "computer":
                labelList.append(35)
                break
            elif row[i] == "power tool":
                labelList.append(36)
                break
            elif row[i] == "abacus":
                labelList.append(37)
                break
            elif row[i] == "farm machine":
                labelList.append(38)
                break
            elif row[i] == "slot machine":
                labelList.append(39)
                break
            elif row[i] == "cash machine":
                labelList.append(40)
                break
            elif row[i] == "mechanism":
                labelList.append(41)
                break
            elif row[i] == "restraint":
                labelList.append(42)
                break
            elif row[i] == "support":
                labelList.append(43)
                break
            elif row[i] == "transducer":
                labelList.append(44)
                break
            elif row[i] == "sunglasses":
                labelList.append(45)
                break
            elif row[i] == "source of illumination":
                labelList.append(46)
                break
            elif row[i] == "eletronic device":
                labelList.append(47)
                break
            elif row[i] == "hard disc":
                labelList.append(48)
                break
            elif row[i] == "reflector":
                labelList.append(49)
                break
            elif row[i] == "trap":
                labelList.append(50)
                break
            elif row[i] == "wing":
                labelList.append(51)
                break
            elif row[i] == "breathing device":
                labelList.append(52)
                break
            elif row[i] == "electric fan":
                labelList.append(53)
                break
            elif row[i] == "filter":
                labelList.append(54)
                break
            elif row[i] == "heater":
                labelList.append(55)
                break
            elif row[i] == "keyboard":
                labelList.append(56)
                break
            elif row[i] == "crane":
                labelList.append(57)
                break
            elif row[i] == "ski":
                labelList.append(58)
                break
            elif row[i] == "whistle":
                labelList.append(59)
                break
            elif row[i] == "lighter":
                labelList.append(60)
                break
            elif row[i] == "pick":
                labelList.append(61)
                break
            elif row[i] == "remote control":
                labelList.append(62)
                break
            elif row[i] == "boat":
                labelList.append(63)
                break
            elif row[i] == "sailing vessel":
                labelList.append(64)
                break
            elif row[i] == "military vehicle":
                labelList.append(65)
                break
            elif row[i] == "missile":
                labelList.append(66)
                break
            elif row[i] == "sled":
                labelList.append(67)
                break
            elif row[i] == "public transport":
                labelList.append(68)
                break
            elif row[i] == "stretcher":
                labelList.append(69)
                break
            elif row[i] == "reservoir":
                labelList.append(70)
                break
            elif row[i] == "bottle":
                labelList.append(71)
                break
            elif row[i] == "coffee mug":
                labelList.append(72)
                break
            elif row[i] == "washbasin":
                labelList.append(73)
                break
            elif row[i] == "jar":
                labelList.append(74)
                break
            elif row[i] == "pot":
                labelList.append(75)
                break
            elif row[i] == "barrel":
                labelList.append(76)
                break
            elif row[i] == "bathtub":
                labelList.append(77)
                break
            elif row[i] == "bucket":
                labelList.append(78)
                break
            elif row[i] == "ladle":
                labelList.append(79)
                break
            elif row[i] == "mortar":
                labelList.append(80)
                break
            elif row[i] == "pitcher":
                labelList.append(81)
                break
            elif row[i] == "tub":
                labelList.append(82)
                break
            elif row[i] == "box":
                labelList.append(83)
                break
            elif row[i] == "dish":
                labelList.append(84)
                break
            elif row[i] == "bag":
                labelList.append(85)
                break
            elif row[i] == "basket":
                labelList.append(86)
                break
            elif row[i] == "ashcan":
                labelList.append(87)
                break
            elif row[i] == "milk can":
                labelList.append(88)
                break
            elif row[i] == "wallet":
                labelList.append(89)
                break
            elif row[i] == "soap dispenser":
                labelList.append(90)
                break
            elif row[i] == "glass":
                labelList.append(91)
                break
            elif row[i] == "measuring cup":
                labelList.append(92)
                break
            elif row[i] == "packet":
                labelList.append(93)
                break
            elif row[i] == "tray":
                labelList.append(94)
                break
            elif row[i] == "piggy bank":
                labelList.append(95)
                break
            elif row[i] == "shaker":
                labelList.append(96)
                break
            elif row[i] == "wooden spoon":
                labelList.append(97)
                break
            elif row[i] == "cassette":
                labelList.append(98)
                break
            elif row[i] == "envelope":
                labelList.append(99)
                break
            elif row[i] == "pot":
                labelList.append(100)
                break
            elif row[i] == "thimble":
                labelList.append(101)
                break
            elif row[i] == "tool":
                labelList.append(102)
                break
            elif row[i] == "utensil":
                labelList.append(103)
                break
            elif row[i] == "space bar":
                labelList.append(104)
                break
            elif row[i] == "stick":
                labelList.append(105)
                break
            elif row[i] == "pen":
                labelList.append(106)
                break
            elif row[i] == "paintbrush":
                labelList.append(107)
                break
            elif row[i] == "cleaning implement":
                labelList.append(108)
                break
            elif row[i] == "rubber eraser":
                labelList.append(109)
                break
            elif row[i] == "paddle":
                labelList.append(110)
                break
            elif row[i] == "pole":
                labelList.append(111)
                break
            elif row[i] == "pencil sharpener":
                labelList.append(112)
                break
            elif row[i] == "racket":
                labelList.append(113)
                break
            elif row[i] == "eletronic equipment":
                labelList.append(114)
                break
            elif row[i] == "game equipment":
                labelList.append(115)
                break
            elif row[i] == "gear":
                labelList.append(116)
                break
            elif row[i] == "photocopier":
                labelList.append(117)
                break
            elif row[i] == "camera":
                labelList.append(118)
                break
            elif row[i] == "sports equipment":
                labelList.append(119)
                break
            elif row[i] == "parachute":
                labelList.append(120)
                break
            elif row[i] == "furniture":
                labelList.append(121)
                break
            elif row[i] == "curtain":
                labelList.append(122)
                break
            elif row[i] == "prayer rug":
                labelList.append(123)
                break
            elif row[i] == "system":
                labelList.append(124)
                break
            elif row[i] == "chain":
                labelList.append(125)
                break
            elif row[i] == "toiletry":
                labelList.append(126)
                break
            elif row[i] == "appliance":
                labelList.append(127)
                break
            elif row[i] == "bath towel":
                labelList.append(128)
                break
            elif row[i] == "bowl":
                labelList.append(129)
                break
            elif row[i] == "petri dish":
                labelList.append(130)
                break
            elif row[i] == "wooden spoon":
                labelList.append(131)
                break
            elif row[i] == "protective covering":
                labelList.append(132)
                break
            elif row[i] == "cloth covering":
                labelList.append(133)
                break
            elif row[i] == "floor cover":
                labelList.append(134)
                break
            elif row[i] == "top":
                labelList.append(135)
                break
            elif row[i] == "book jacket":
                labelList.append(136)
                break
            elif row[i] == "shoji":
                labelList.append(137)
                break
            elif row[i] == "cloak":
                labelList.append(138)
                break
            elif row[i] == "mask":
                labelList.append(139)
                break
            elif row[i] == "comic book":
                labelList.append(140)
                break
            elif row[i] == "necklace":
                labelList.append(141)
                break
            elif row[i] == "totem pole":
                labelList.append(142)
                break
            elif row[i] == "rain barrel":
                labelList.append(143)
                break
            elif row[i] == "fabric":
                labelList.append(144)
                break
            elif row[i] == "sheet":
                labelList.append(145)
                break
            elif row[i] == "stage":
                labelList.append(146)
                break
            elif row[i] == "pillow":
                labelList.append(147)
                break
            elif row[i] == "playting":
                labelList.append(148)
                break
            elif row[i] == "fruit":
                labelList.append(149)
                break
            elif row[i] == "sandbar":
                labelList.append(150)
                break
            elif row[i] == "beverage":
                labelList.append(151)
                break
            elif row[i] == "geological formation":
                labelList.append(152)
                break
            elif row[i] == "nutriment":
                labelList.append(153)
                break
            elif row[i] == "vegetable":
                labelList.append(154)
                break
            elif row[i] == "foodstuff":
                labelList.append(155)
                break
            elif row[i] == "sandwich":
                labelList.append(156)
                break
            elif row[i] == "bagel":
                labelList.append(157)
                break
            elif row[i] == "guacamole":
                labelList.append(158)
                break
            elif row[i] == "chocolate sauce":
                labelList.append(159)
                break
            elif row[i] == "bubble":
                labelList.append(160)
                break
            elif row[i] == "carbonara":
                labelList.append(161)
                break
            elif row[i] == "French loaf":
                labelList.append(162)
                break
            elif row[i] == "menu":
                labelList.append(163)
                break
            elif row[i] == "pretzel":
                labelList.append(164)
                break
            elif row[i] == "street sign":
                labelList.append(165)
                break
            elif row[i] == "toilet tissue":
                labelList.append(166)
                break
            elif row[i] == "traffic light":
                labelList.append(167)
                break
            elif row[i] == "sunglass":
                labelList.append(168)
                break
            elif row[i] == "teddy":
                labelList.append(169)
                break
            elif row[i] == "cheeseburger":
                labelList.append(170)
                break
            elif row[i] == "barrier":
                labelList.append(171)
                break
            elif row[i] == "fungus":
                labelList.append(172)
                break
            elif row[i] == "person":
                labelList.append(173)
                break
            elif row[i] == "flower":
                labelList.append(174)
                break
            elif row[i] == "cooking utensil":
                labelList.append(175)
                break
            elif row[i] == "electronic equipment":
                labelList.append(176)
                break
            elif row[i] == "timepiece":
                labelList.append(177)
                break
            elif row[i] == "space shuttle":
                labelList.append(178)
                break
            elif row[i] == "crane": # construction crane
                labelList.append(179)
                break
            elif row[i] == "electric fan":
                labelList.append(180)
                break
            elif row[i] == "magnetic compass":
                labelList.append(181)
                break
            elif row[i] == "electronic device":
                labelList.append(182)
                break
            elif row[i] == "decoration":
                labelList.append(183)
                break
            elif row[i] == "pole":
                labelList.append(184)
                break
            """
            if  i == 7:
                counter = counter +1
                print("nicht gefunden " + str(index +2))
            #print(row[i]
    if counter == 0 :
        print("ALLES GELABELT")
    else :
        print(counter) 
    return labelList

# %%
path = "Imagenet-Mapping.ods"
#path = "testImagenetMapping.ods"

# by default the first sheet is imported
df = read_ods(path)

labels = getLabelList(df)

print(len(labels))
#df.drop(["Label"], axis=1)

for index,label in enumerate(labels):
    df.at[index, 'Labels'] = label

print("hier")
sorted = list(dict.fromkeys(labels))

sorted.sort()
print(sorted)
# Out:
# nicht gefunden 400
# nicht gefunden 401
# nicht gefunden 402
# nicht gefunden 403
# nicht gefunden 404
# nicht gefunden 405
# nicht gefunden 406
# nicht gefunden 407
# nicht gefunden 408
# nicht gefunden 409
# nicht gefunden 410
# nicht gefunden 411
# nicht gefunden 412
# nicht gefunden 413
# nicht gefunden 414
# nicht gefunden 415
# nicht gefunden 416
# nicht gefunden 417
# nicht gefunden 418
# nicht gefunden 419
# nicht gefunden 420
# nicht gefunden 421
# nicht gefunden 422
# nicht gefunden 423
# nicht gefunden 424
# nicht gefunden 425
# nicht gefunden 426
# nicht gefunden 427
# nicht gefunden 428
# nicht gefunden 429
# nicht gefunden 430
# nicht gefunden 431
# nicht gefunden 432
# nicht gefunden 433
# nicht gefunden 434
# nicht gefunden 435
# nicht gefunden 436
# nicht gefunden 437
# nicht gefunden 438
# nicht gefunden 439
# nicht gefunden 440
# nicht gefunden 441
# nicht gefunden 442
# nicht gefunden 443
# nicht gefunden 444
# nicht gefunden 445
# nicht gefunden 446
# ...

# %%
print(df[:40])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_231/2216017246.py in <module>
# ----> 1 print(df[:40])
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from pyexcel_ods import save_data
from collections import OrderedDict

def save_ods_from_df(df, target_ods_file):
    # Change everything to string since we're just writing
    df = df.astype(str)
    # Initiliaze data to be written as an empty list, as pyods needs a list to write
    whole_data_list = []
    # Initiliaze the empty dict() for the data
    d = OrderedDict()
    # Write the columns first to be the first entries 
    whole_data_list.append(list(df.columns))
    # loop through data frame and update the data list
    for index, row in df.iterrows():
        whole_data_list.append(list(row.values))
    # Populate dict() with updated data list
    d.update({"Moved sheet": whole_data_list})
    # Finally call save_data() from pyods to store the ods file
    save_data(target_ods_file, d)
    
save_ods_from_df(df, "testImageNetMapping1.ods")
